# %% [markdown]
# ### Plotting with Gadfly.jl
#
# * [GitHub Repository](https://github.com/GiovineItalia/Gadfly.jl)
# * [Documentation](http://gadflyjl.org/stable/)

# %% [markdown]
# ## Imports

# %%
using Gadfly
using DataFrames, RDatasets
# Out:
# INFO: Recompiling stale cache file /Users/mrestrep/.julia/lib/v0.6/CodecZlib.ji for module CodecZlib.
# INFO: Recompiling stale cache file /Users/mrestrep/.julia/lib/v0.6/Gadfly.ji for module Gadfly.
# INFO: Recompiling stale cache file /Users/mrestrep/.julia/lib/v0.6/RDatasets.ji for module RDatasets.

# %% [markdown]
# # Basics
#
# ## Simple line scatter
#
# * Pass data keyword arguments inputs

# %%
function linescatter()
    x = [1, 2, 3, 4]
    y = [10, 15, 13, 17]
    plot(x=x,y=y, Geom.line)
end
linescatter()
# Out:
# Plot(...)

# %% [markdown]
# ### Customize and add multiple traces to one plot
#
# * Each trace is a layer with its own aesthetics
#
# **Challenge:** How to plot dashes?

# %%
function multiple_scatter_traces()
    x=1:4
    l1 = layer(x = x, y = [10, 15, 13, 17],  Geom.point)
    l2 = layer(x = x, y = [16, 5, 11, 9], Geom.line)
    l3 = layer(x = x, y = [12, 9, 15, 12], Geom.point, Geom.line)
    l4 = layer(x = x, y = [5, 10, 8, 12], Geom.line)
    plot(l1, l2, l3, l4)
end
multiple_scatter_traces()
# Out:
# Plot(...)

# %% [markdown]
# ### Data labels and Figure Layout
#
# * Add the array of labels as an attribute to each trace
# * Layout modifies the "Figure Pane Attributes"

# %%
function data_labels()
    x = 1:5
    y1 = [1, 6, 3, 6, 1]
    y2 = [4, 1, 7, 1, 4]
    y1_labels = ["A-1", "A-2", "A-3", "A-4", "A-5"]
    y2_labels = ["B-a", "B-b", "B-c", "B-d", "B-e"]

    l1 = layer(x = x, y = y1, label=y1_labels, Geom.label, Geom.point)
    l2 = layer(x = x, y = y2, label=y2_labels, Geom.label, Geom.point) 
    plot(l1,l2)
end
data_labels()
# Out:
# Plot(...)

# %% [markdown]
# ## Area

# %%
function area1()
end
area1()

# %% [markdown]
# ## Other visual interpretations of Matrix Data and Subplots

# %%
function matrix_subplots()

end

matrix_subplots()

# %% [markdown]
# ## Advanced Layouts

# %%
function advanced_layouts()

end
advanced_layouts()

# %% [markdown]
# ## Stats Plots

# %%
function grouped_bar_example()

end

grouped_bar_example()

# %%
function stacked_bar_example()
    
end
stacked_bar_example()

# %%
function two_hists()

end

two_hists()

# %% [markdown]
# ## Box (Whisker) Plots

# %%
function box_plot()
   
end
box_plot()

# %% [markdown]
# ### Using DataFrames

# %%
function data_frame_scatter()
    iris = dataset("datasets", "iris");
    display(head(iris))
end

data_frame_scatter()
# Out:
# INFO: Precompiling module RData.
# WARNING: Method definition unix2zdt(Real) in module TimeZones at /Users/mrestrep/.julia/plotting_tutorial/v0.6/TimeZones/src/conversions.jl:122 overwritten in module RData at /Users/mrestrep/.julia/plotting_tutorial/v0.6/RData/src/convert.jl:201.
# 6×5 DataFrames.DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼─────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa  │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa  │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa  │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa  │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa  │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa  │
# WARNING: Method definition unix2zdt(Real) in module TimeZones at /Users/mrestrep/.julia/plotting_tutorial/v0.6/TimeZones/src/conversions.jl:122 overwritten in module RData at /Users/mrestrep/.julia/plotting_tutorial/v0.6/RData/src/convert.jl:201.
